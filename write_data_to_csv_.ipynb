# %% [markdown]
# <a href="https://colab.research.google.com/github/BingHungLee/Heat_Transfer/blob/master/write_data_to_csv_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#上載 BPN_CSV
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))

# 確認 BPN_CSV 是否已上載
# !ls *.* -l
# Out:
#      <input type="file" id="files-b665e1ac-f8d2-4b48-a541-5e7ffd995c14" name="files[]" multiple disabled />
#      <output id="result-b665e1ac-f8d2-4b48-a541-5e7ffd995c14">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving BPN_CSV.csv to BPN_CSV.csv
# User uploaded file "BPN_CSV.csv" with length 82425 bytes
# -rw-r--r-- 1 root root 82425 Dec  4 06:25 BPN_CSV.csv

# %%
# use Pandas to read BPN_CSV
import pandas as pd
df = pd.read_csv('BPN_CSV.csv')
print(df)
# Out:
#                                             BPN_DATA
# 0                                        0.805612214
# 1                                              [111]
# 2                                           identity
# 3                                              [111]
# 4                                      solver='lbfgs
# ...                                              ...
# 5605                                      Best_[422]
# 5606           Ann_BestMLPRegressor(tanh beta_1=0.9,
# 5607  beta_2=0.999early_stopping=Falseepsilon=1e-08,
# 5608                                           [422]
# 5609                                   solver='lbfgs
#
# [5610 rows x 1 columns]

# %%
df.loc[0:2,]
# Out:
#       BPN_DATA
# 0  0.805612214
# 1        [111]
# 2     identity

# %%
df.describe()
# Out:
#                                               BPN_DATA
# count                                             5610
# unique                                            1076
# top     beta_2=0.999early_stopping=Falseepsilon=1e-08,
# freq                                               510

# %%
df.loc[1].tolist()
# Out:
# ['[111]']

# %%
df.loc[:,]
# Out:
#                                             BPN_DATA
# 0                                        0.805612214
# 1                                              [111]
# 2                                           identity
# 3                                              [111]
# 4                                      solver='lbfgs
# ...                                              ...
# 5605                                      Best_[422]
# 5606           Ann_BestMLPRegressor(tanh beta_1=0.9,
# 5607  beta_2=0.999early_stopping=Falseepsilon=1e-08,
# 5608                                           [422]
# 5609                                   solver='lbfgs
#
# [5610 rows x 1 columns]

# %% [markdown]
# https://pythonhow.com/accessing-dataframe-columns-rows-and-cells/

# %% [markdown]
# https://thispointer.com/pandas-6-different-ways-to-iterate-over-rows-in-a-dataframe-update-while-iterating-row-by-row/

# %% [markdown]
# https://blog.csdn.net/xiangxianghehe/article/details/72615711
# pandas DataFrame数据转为list

# %%
import numpy as np
BPN_NP = np.array(df)#np.ndarray()
BPN_LIST=BPN_NP.tolist()#list
print(BPN_LIST)
# Out:
# [['0.805612214'], ['[111]'], ['identity'], ['[111]'], ["solver='lbfgs"], ['0.765505753'], ['[112]'], ['identity'], ['[112]'], ["solver='lbfgs"], ['0.779739806'], ['[113]'], ['identity'], ['[113]'], ["solver='lbfgs"], ['0.490762529'], ['[114]'], ['identity'], ['[114]'], ["solver='lbfgs"], ['0.785237412'], ['[121]'], ['identity'], ['[121]'], ["solver='lbfgs"], ['0.816561774'], ['[122]'], ['identity'], ['[122]'], ["solver='lbfgs"], ['0.531195518'], ['[123]'], ['identity'], ['[123]'], ["solver='lbfgs"], ['0.49789161'], ['[124]'], ['identity'], ['[124]'], ["solver='lbfgs"], ['0.788421208'], ['[131]'], ['identity'], ['[131]'], ["solver='lbfgs"], ['0.497019436'], ['[132]'], ['identity'], ['[132]'], ["solver='lbfgs"], ['0.518503819'], ['[133]'], ['identity'], ['[133]'], ["solver='lbfgs"], ['0.748670976'], ['[134]'], ['identity'], ['[134]'], ["solver='lbfgs"], ['0.476663342'], ['[141]'], ['identity'], ['[141]'], ["solver='lbfgs"], ['0.836403277'], ['[142]'], ['identity'], ['[142]'], ["solver='lbfgs"], ['0.476705763'], ['[143]'], ['identity'], ['[143]'], ["solver='lbfgs"], ['0.476499376'], ['[144]'], ['identity'], ['[144]'], ["solver='lbfgs"], ['0.490258139'], ['[211]'], ['identity'], ['[211]'], ["solver='lbfgs"], ['0.476767137'], ['[212]'], ['identity'], ['[212]'], ["solver='lbfgs"], ['0.87235425'], ['[213]'], ['identity'], ['[213]'], ["solver='lbfgs"], ['0.476474903'], ['[214]'], ['identity'], ['[214]'], ["solver='lbfgs"], ['0.488339923'], ['[221]'], ['identity'], ['[221]'], ["solver='lbfgs"], ['0.476698654'], ['[222]'], ['identity'], ['[222]'], ["solver='lbfgs"], ['0.477201429'], ['[223]'], ['identity'], ['[223]'], ["solver='lbfgs"], ['0.581342121'], ['[224]'], ['identity'], ['[224]'], ["solver='lbfgs"], ['0.775276616'], ['[231]'], ['identity'], ['[231]'], ["solver='lbfgs"], ['0.523847854'], ['[232]'], ['identity'], ['[232]'], ["solver='lbfgs"], ['0.601907921'], ['[233]'], ['identity'], ['[233]'], ["solver='lbfgs"], ['0.487572706'], ['[234]'], ['identity'], ['[234]'], ["solver='lbfgs"], ['0.476675496'], ['[241]'], ['identity'], ['[241]'], ["solver='lbfgs"], ['0.476501564'], ['[242]'], ['identity'], ['[242]'], ["solver='lbfgs"], ['0.552203157'], ['[243]'], ['identity'], ['[243]'], ["solver='lbfgs"], ['0.503912828'], ['[244]'], ['identity'], ['[244]'], ["solver='lbfgs"], ['0.476598935'], ['[311]'], ['identity'], ['[311]'], ["solver='lbfgs"], ['0.476468882'], ['[312]'], ['identity'], ['[312]'], ["solver='lbfgs"], ['0.476470179'], ['[313]'], ['identity'], ['[313]'], ["solver='lbfgs"], ['0.856788601'], ['[314]'], ['identity'], ['[314]'], ["solver='lbfgs"], ['0.477841342'], ['[321]'], ['identity'], ['[321]'], ["solver='lbfgs"], ['0.508546389'], ['[322]'], ['identity'], ['[322]'], ["solver='lbfgs"], ['0.573900657'], ['[323]'], ['identity'], ['[323]'], ["solver='lbfgs"], ['0.761665916'], ['[324]'], ['identity'], ['[324]'], ["solver='lbfgs"], ['0.65820761'], ['[331]'], ['identity'], ['[331]'], ["solver='lbfgs"], ['0.48018399'], ['[332]'], ['identity'], ['[332]'], ["solver='lbfgs"], ['0.500315972'], ['[333]'], ['identity'], ['[333]'], ["solver='lbfgs"], ['0.480783937'], ['[334]'], ['identity'], ['[334]'], ["solver='lbfgs"], ['0.479475077'], ['[341]'], ['identity'], ['[341]'], ["solver='lbfgs"], ['0.678789841'], ['[342]'], ['identity'], ['[342]'], ["solver='lbfgs"], ['0.476500237'], ['[343]'], ['identity'], ['[343]'], ["solver='lbfgs"], ['0.5055424'], ['[344]'], ['identity'], ['[344]'], ["solver='lbfgs"], ['0.795334771'], ['[411]'], ['identity'], ['[411]'], ["solver='lbfgs"], ['0.715246938'], ['[412]'], ['identity'], ['[412]'], ["solver='lbfgs"], ['0.48743104'], ['[413]'], ['identity'], ['[413]'], ["solver='lbfgs"], ['0.476469624'], ['[414]'], ['identity'], ['[414]'], ["solver='lbfgs"], ['0.476650392'], ['[421]'], ['identity'], ['[421]'], ["solver='lbfgs"], ['0.477522876'], ['[422]'], ['identity'], ['[422]'], ["solver='lbfgs"], ['0.476976455'], ['[423]'], ['identity'], ['[423]'], ["solver='lbfgs"], ['0.476507376'], ['[424]'], ['identity'], ['[4 ...

# %%
count = 0
print(len(df.index))
for i in range(len(df.index)):
  count = count + 1
  if count == 4:
    count = 0
print(count)
# Out:
# 5610
# 2
